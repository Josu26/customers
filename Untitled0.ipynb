# %% [markdown]
# <a href="https://colab.research.google.com/github/Josu26/customers/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

# Cargar datos desde un archivo CSV
df = pd.read_csv('https://raw.githubusercontent.com/Josu26/customers/main/Customers.csv')

# %%
df = pd.read_csv('https://github.com/Josu26/customers/blob/main/Customers.csv', nrows=10)
print(df.head())
# Out:
#                                      <!DOCTYPE html>
# 0  <html lang="en" data-color-mode="auto" data-li...
# 1                                             <head>
# 2                             <meta charset="utf-8">
# 3    <link rel="dns-prefetch" href="https://githu...
# 4    <link rel="dns-prefetch" href="https://avata...

# %%
# Mostrar los primeros cinco registros de los datos
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
# Verificar si hay valores faltantes en nuestros datos
print(df.isnull().sum())
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
# Eliminar filas con valores faltantes
df = df.dropna()

# %%
# Verificar y eliminar duplicados
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# 0

# %%
# Ver las columnas
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income ($)',
#        'Spending Score (1-100)', 'Profession', 'Work Experience',
#        'Family Size'],
#       dtype='object')

# %%
# Seleccionar solo las columnas necesarias
df = df[['CustomerID', 'Age', 'Profession']]

# %%
# Guardar el DataFrame en un archivo CSV
df.to_csv('customers_processed.csv', index=False)

# %%
# Importamos las librerias necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargamos los datos de nuevo
df = pd.read_csv('https://raw.githubusercontent.com/Josu26/Customers/main/Customers.csv')

# %%
print(df.describe())
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
plt.hist(df['Age'], bins=10)
plt.title('Distribución de edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.countplot(x='Profession', data=df)
plt.title('Cantidad de clientes por profesión')
plt.xlabel('Profesión')
plt.ylabel('Cantidad')
plt.show()

# %%
sns.scatterplot(x='Age', y='Annual Income ($)', data=df)
plt.title('Ingresos versus edad')
plt.xlabel('Edad')
plt.ylabel('Ingresos')
plt.show()

# %%
install.packages("dplyr")
install.packages("ggplot2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06606419e0a6> in <cell line: 1>()
# ----> 1 install.packages("dplyr")
#       2 install.packages("ggplot2")
#
# NameError: name 'install' is not defined
